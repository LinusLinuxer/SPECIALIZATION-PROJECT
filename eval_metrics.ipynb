# %% [markdown]
# A Notebook for evaluating the AI trained in 'CNN-RNN-CTC'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("eval_metrics.csv")

# %%
df.head()
# Out:
#    epoch    ctc_loss    val_loss       cer  wer
# 0    0.0  621.641235  388.920227  0.979353  1.0
# 1    1.0  395.006378  364.033875  0.979353  1.0
# 2    2.0  370.052643  345.756561  0.979353  1.0
# 3    3.0  346.702576  317.886017  0.979353  1.0
# 4    4.0  328.510590  308.290222  0.979353  1.0

# %%
df.plot(
    x="epoch", y=["val_loss", "ctc_loss"], kind="line", marker="o"
)
plt.xlabel("Epoch")
plt.ylabel("Metric Value")
plt.title("Loss Over Epochs")
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
df.plot(
    x="epoch", y=["cer", "wer"], kind="line", marker="o"
)
plt.xlabel("Epoch")
plt.ylabel("Metric Value")
plt.title("CER/WER Over Epochs")
plt.legend(loc="best")
plt.grid(True)
plt.show()
