# %% [markdown]
# A Notebook for evaluating the AI trained in 'CNN-RNN-CTC'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("eval_metrics.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  epoch        loss    val_loss    ctc loss  cer  wer
# 0           0    0.0  232.555420  150.409637  232.555420  1.0  1.0
# 1           1    1.0  146.916016  149.129059  146.916016  1.0  1.0
# 2           2    2.0  146.384689  148.859940  146.384689  1.0  1.0
# 3           3    3.0  145.989792  150.234650  145.989792  1.0  1.0
# 4           4    4.0  146.471008  148.999756  146.471008  1.0  1.0

# %%
df.plot(
    x="epoch", y=["loss", "val_loss", "ctc loss"], kind="line", marker="o"
)
plt.xlabel("Epoch")
plt.ylabel("Metric Value")
plt.title("Loss Over Epochs")
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
df.plot(
    x="epoch", y=["cer", "wer"], kind="line", marker="o"
)
plt.xlabel("Epoch")
plt.ylabel("Metric Value")
plt.title("CER/WER Over Epochs")
plt.legend(loc="best")
plt.grid(True)
plt.show()
