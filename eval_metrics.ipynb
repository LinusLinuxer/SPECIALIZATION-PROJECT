# %% [markdown]
# A Notebook for evaluating the AI trained in 'CNN-RNN-CTC'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("eval_metrics.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  epoch    ctc loss    val_loss       cer  wer
# 0           0    0.0  404.394714  277.094940  0.979602  1.0
# 1           1    1.0  281.796478  271.480591  0.979602  1.0
# 2           2    2.0  277.406982  265.539185  0.979602  1.0
# 3           3    3.0  275.408264  263.565033  0.979602  1.0
# 4           4    4.0  273.792725  261.629181  0.979602  1.0

# %%
df.plot(
    x="epoch", y=["val_loss", "ctc loss"], kind="line", marker="o"
)
plt.xlabel("Epoch")
plt.ylabel("Metric Value")
plt.title("Loss Over Epochs")
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
df.plot(
    x="epoch", y=["cer", "wer"], kind="line", marker="o"
)
plt.xlabel("Epoch")
plt.ylabel("Metric Value")
plt.title("CER/WER Over Epochs")
plt.legend(loc="best")
plt.grid(True)
plt.show()
